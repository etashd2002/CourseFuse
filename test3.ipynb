# %%
from neo4j import GraphDatabase
uri1      = "neo4j://localhost:7687" # in Neo4j Desktop
                              # custom URL for Sandbox or Aura
user1     = "neo4j"            # your user name 
                              # default is always "neo4j" 
                              # unless you have changed it. 
password1 = "Sed@261510040202"
driver1 = GraphDatabase.driver(uri=uri1,auth=(uri1,password1),database='etash')

uri2      = "neo4j://localhost:7687" # in Neo4j Desktop
                              # custom URL for Sandbox or Aura
user2     = "neo4j"            # your user name 
                              # default is always "neo4j" 
                              # unless you have changed it. 
password2 = "Sed@261510040202"
driver2 = GraphDatabase.driver(uri=uri2,auth=(uri2,password2),database='etash')

# %%
import nxneo4j as nx

# %%
G1 = nx.Graph(driver1)
G2 = nx.Graph(driver2)

# %%
G1.delete_all()  #This will delete all the data, be careful
G2.delete_all()  #This will delete all the data, be careful

# %%
G1.relationship_type = 'has'
G1.add_node('Machine Learning')
G1.add_node('Introduction to Machine Learning', mod_name='Module 1')
G1.add_node('Learning with Regression and Trees', mod_name='Module 2')
G1.add_node('Ensemble Learning', mod_name='Module 3')
G1.add_node('Learning with Classification', mod_name='Module 4')
G1.add_node('Learning with Clustering' ,mod_name='Module 5')
G1.add_node('Dimensionality Reduction ' ,mod_name='Module 6')


G1.add_edge('Machine Learning','Introduction to Machine Learning',weight=4)
G1.add_edge('Machine Learning','Learning with Regression and Trees',weight=9)
G1.add_edge('Machine Learning','Ensemble Learning',weight=6)
G1.add_edge('Machine Learning','Learning with Classification',weight=8)
G1.add_edge('Machine Learning','Learning with Clustering',weight=7)
G1.add_edge('Machine Learning','Dimensionality Reduction ',weight=5)

#Mod 1.1
G1.add_edge('Introduction to Machine Learning','Types of Machine Learning')
G1.add_edge('Introduction to Machine Learning','Issues in Machine Learning')
G1.add_edge('Introduction to Machine Learning','Application of Machine Learning')
G1.add_edge('Introduction to Machine Learning','Steps in developing a ML Application')

#Mod 1.2
G1.add_edge('Introduction to Machine Learning','Training Error')
G1.add_edge('Introduction to Machine Learning','Generalization error')
G1.add_edge('Introduction to Machine Learning','Overfitting')
G1.add_edge('Introduction to Machine Learning','Underfitting')
G1.add_edge('Introduction to Machine Learning','Bias-Variance Trade Off')

#Mod 2.1
G1.add_edge('Learning with Regression and Trees','Linear Regression')
G1.add_edge('Learning with Regression and Trees','Multivariate Linear Regression')
G1.add_edge('Learning with Regression and Trees','Logistic Regression')

#Mod 2.2
G1.add_edge('Learning with Regression and Trees','Decision Trees')
G1.add_edge('Learning with Regression and Trees','Decision Trees using Gini Index')
G1.add_edge('Learning with Regression and Trees','Classification and Regression Trees')

#Mod 2.3
G1.add_edge('Learning with Regression and Trees','Confusion Matrix')
G1.add_edge('Learning with Regression and Trees','[Kappa Statistics]')
G1.add_edge('Learning with Regression and Trees','Sensitivity')
G1.add_edge('Learning with Regression and Trees','Specificity')
G1.add_edge('Learning with Regression and Trees','Precision')
G1.add_edge('Learning with Regression and Trees','Recall')
G1.add_edge('Learning with Regression and Trees','F-measure')
G1.add_edge('Learning with Regression and Trees','ROC curve')

#Mod 3.1
G1.add_edge('Ensemble Learning','Understanding Ensembles')
G1.add_edge('Ensemble Learning','K-fold cross validation')
G1.add_edge('Ensemble Learning','Boosting')
G1.add_edge('Ensemble Learning','Stumping')
G1.add_edge('Ensemble Learning','XGBoost')

#Mod 3.2
G1.add_edge('Ensemble Learning','Bagging')
G1.add_edge('Ensemble Learning','Subagging')
G1.add_edge('Ensemble Learning','Random Forest')
G1.add_edge('Ensemble Learning','Comparison with Boosting')
G1.add_edge('Ensemble Learning','Different ways to combine classifiers')

#Mod 4.1
G1.add_edge('Learning with Classification','Constrained Optimization')
G1.add_edge('Learning with Classification','Optimal decision boundary')
G1.add_edge('Learning with Classification','Margins and support vectors')
G1.add_edge('Learning with Classification','SVM as constrained optimization problem')
G1.add_edge('Learning with Classification','Quadratic Programming')
G1.add_edge('Learning with Classification','SVM for linear and nonlinear classification')
G1.add_edge('Learning with Classification','Basics of Kernel trick')

#Mod 4.2
G1.add_edge('Learning with Classification','Support Vector Regression')
G1.add_edge('Learning with Classification','Multiclass Classification')

#Mod 5.1
G1.add_edge('Learning with Clustering','Introduction to clustering')
G1.add_edge('Learning with Clustering','Overview of distance metrics')
G1.add_edge('Learning with Clustering','Major clustering approaches')

#Mod 5.2
G1.add_edge('Learning with Clustering','Clustering with minimal spanning tree')
G1.add_edge('Learning with Clustering','Expectation Maximization Algorithm')
G1.add_edge('Learning with Clustering','Density Based Clustering: DBSCAN')

#Mod 6.1
G1.add_edge('Dimensionality Reduction ','Dimensionality Reduction Techniques')
G1.add_edge('Dimensionality Reduction ','Principal Component Analysis')
G1.add_edge('Dimensionality Reduction ','Linear Discriminant Analysis')
G1.add_edge('Dimensionality Reduction ','Singular Valued Decomposition')

# %%
list(G1.edges(data=True))
# Out:
# [('Learning with Classification', 'Basics of Kernel trick', {}),
#  ('Learning with Classification', 'Support Vector Regression', {}),
#  ('Learning with Classification', 'Multiclass Classification', {}),
#  ('Learning with Clustering', 'Introduction to clustering', {}),
#  ('Learning with Clustering', 'Overview of distance metrics', {}),
#  ('Learning with Clustering', 'Major clustering approaches', {}),
#  ('Learning with Clustering', 'Clustering with minimal spanning tree', {}),
#  ('Learning with Clustering', 'Expectation Maximization Algorithm', {}),
#  ('Learning with Clustering', 'Density Based Clustering: DBSCAN', {}),
#  ('Dimensionality Reduction ', 'Singular Valued Decomposition', {}),
#  ('Machine Learning', 'Introduction to Machine Learning', {'weight': 4}),
#  ('Machine Learning', 'Learning with Regression and Trees', {'weight': 9}),
#  ('Machine Learning', 'Ensemble Learning', {'weight': 6}),
#  ('Machine Learning', 'Learning with Classification', {'weight': 8}),
# ...

# %%
G2.relationship_type = 'has'
G2.add_node('Artificial Intelligence')

G2.add_node('Introduction to Artificial Intelligence', mod_name='Module 1')
G2.add_node('Intelligent Agents', mod_name='Module 2')
G2.add_node('Problem solving', mod_name='Module 3')
G2.add_node('Knowledge and Reasoning', mod_name='Module 4')
G2.add_node('Planning and Learning' ,mod_name='Module 5')
G2.add_node('AI Applications' ,mod_name='Module 6')

G2.add_edge('Artificial Intelligence','Introduction to Artificial Intelligence',weight=4)
G2.add_edge('Artificial Intelligence','Intelligent Agents',weight=4)
G2.add_edge('Artificial Intelligence','Problem solving',weight=10)
G2.add_edge('Artificial Intelligence','Knowledge and Reasoning',weight=12)
G2.add_edge('Artificial Intelligence','Planning and Learning',weight=5)
G2.add_edge('Artificial Intelligence','AI Applications',weight=4)

#Mod 1.1
G2.add_edge('Introduction to Artificial Intelligence','Introduction')
G2.add_edge('Introduction to Artificial Intelligence','History of Artificial Intelligence')
G2.add_edge('Introduction to Artificial Intelligence','Intelligent Systems')
G2.add_edge('Introduction to Artificial Intelligence','Categorization of Intelligent System')
G2.add_edge('Introduction to Artificial Intelligence','Components of AI Program')
G2.add_edge('Introduction to Artificial Intelligence','Foundations of AI')
G2.add_edge('Introduction to Artificial Intelligence','Sub-areas of AI')
G2.add_edge('Introduction to Artificial Intelligence','Applications of AI')
G2.add_edge('Introduction to Artificial Intelligence','Current trends in AI')

#Mod 2.1
G2.add_edge('Intelligent Agents','Agents and Environments')
G2.add_edge('Intelligent Agents','Concept of rationality')
G2.add_edge('Intelligent Agents','Nature of environment')
G2.add_edge('Intelligent Agents','Structure of Agents')
G2.add_edge('Intelligent Agents','Types of Agents')
G2.add_edge('Intelligent Agents','Learning Agent')

#Mod 2.2
G2.add_edge('Intelligent Agents','Solving problem by Searching')
G2.add_edge('Intelligent Agents','Problem Solving Agent')
G2.add_edge('Intelligent Agents','Formulating Problems')
G2.add_edge('Intelligent Agents','Example Problems')

#Mod 3.1
G2.add_edge('Problem solving','Uninformed Search Methods')
G2.add_edge('Problem solving','Breadth First Search')
G2.add_edge('Problem solving','Depth First Search')
G2.add_edge('Problem solving','Depth Limited Search')
G2.add_edge('Problem solving','Depth First Iterative Deepening ')
G2.add_edge('Problem solving','Informed Search Methods')
G2.add_edge('Problem solving','Greedy best first Search')
G2.add_edge('Problem solving','A* Search')
G2.add_edge('Problem solving','Memory bounded heuristic Search')

#Mod 3.2
G2.add_edge('Problem solving','Local Search Algorithms and Optimization Problems')
G2.add_edge('Problem solving','Hill climbing search Simulated annealing')
G2.add_edge('Problem solving','Genetic algorithms')

#Mod 3.3
G2.add_edge('Problem solving','Adversarial Search')
G2.add_edge('Problem solving','Game Playing')
G2.add_edge('Problem solving','Min-Max Search')
G2.add_edge('Problem solving','Alpha Beta Pruning ')

#Mod 4.1
G2.add_edge('Knowledge and Reasoning','Knowledge based Agents')
G2.add_edge('Knowledge and Reasoning','Brief Overview of propositional logic')
G2.add_edge('Knowledge and Reasoning','First Order Logic')
G2.add_edge('Knowledge and Reasoning','Syntax and Semantic')
G2.add_edge('Knowledge and Reasoning','Inference in FOL')
G2.add_edge('Knowledge and Reasoning','Forward chaining')
G2.add_edge('Knowledge and Reasoning','backward Chaining')

#Mod 4.2
G2.add_edge('Knowledge and Reasoning','Knowledge Engineering in First-Order Logic')
G2.add_edge('Knowledge and Reasoning','Unification')
G2.add_edge('Knowledge and Reasoning','Resolution')

#Mod 4.3
G2.add_edge('Knowledge and Reasoning','Uncertain Knowledge and Reasoning')
G2.add_edge('Knowledge and Reasoning','Uncertainty')
G2.add_edge('Knowledge and Reasoning','Representing knowledge in an uncertain domain')
G2.add_edge('Knowledge and Reasoning','semantics of belief network')
G2.add_edge('Knowledge and Reasoning','Simple Inference in belief network')

#Mod 5.1
G2.add_edge('Planning and Learning','The planning problem')
G2.add_edge('Planning and Learning','Planning with state space search')
G2.add_edge('Planning and Learning','Partial order planning')
G2.add_edge('Planning and Learning','Hierarchical planning')
G2.add_edge('Planning and Learning','Conditional Planning')

#Mod 5.2
G2.add_edge('Planning and Learning','Forms of Learning')
G2.add_edge('Planning and Learning','Theory of Learning')
G2.add_edge('Planning and Learning','PAC learning')
G2.add_edge('Planning and Learning','Introduction to statistical learning')
G2.add_edge('Planning and Learning','Introduction to reinforcement learning')
G2.add_edge('Planning and Learning','Learning from Rewards')
G2.add_edge('Planning and Learning','Passive Reinforcement Learning,')
G2.add_edge('Planning and Learning','Active reinforcement Learning')

#Mod 6.1
G2.add_edge('AI Applications',' Introduction to NLP')
G2.add_edge('AI Applications','Language models')
G2.add_edge('AI Applications','Grammars')
G2.add_edge('AI Applications','Parsing')
G2.add_edge('AI Applications','Robotics')
G2.add_edge('AI Applications','Robots')
G2.add_edge('AI Applications','Robot hardware')
G2.add_edge('AI Applications','Problems Robotics can solve')
G2.add_edge('AI Applications','Applications in Healthcare')
G2.add_edge('AI Applications','Retail')
G2.add_edge('AI Applications','Banking')

# %%
list(G2.edges(data=True))
# Out:
# [('Learning with Classification', 'Basics of Kernel trick', {}),
#  ('Learning with Classification', 'Support Vector Regression', {}),
#  ('Learning with Classification', 'Multiclass Classification', {}),
#  ('Learning with Clustering', 'Introduction to clustering', {}),
#  ('Learning with Clustering', 'Overview of distance metrics', {}),
#  ('Learning with Clustering', 'Major clustering approaches', {}),
#  ('Learning with Clustering', 'Clustering with minimal spanning tree', {}),
#  ('Learning with Clustering', 'Expectation Maximization Algorithm', {}),
#  ('Learning with Clustering', 'Density Based Clustering: DBSCAN', {}),
#  ('Dimensionality Reduction ', 'Singular Valued Decomposition', {}),
#  ('Artificial Intelligence',
#   'Introduction to Artificial Intelligence',
#   {'weight': 4}),
#  ('Artificial Intelligence', 'Intelligent Agents', {'weight': 4}),
#  ('Artificial Intelligence', 'Problem solving', {'weight': 10}),
# ...

# %%
G1.base_params()
# Out:
# {'direction': 'UNDIRECTED',
#  'node_label': 'Node',
#  'relationship_type': 'has',
#  'identifier_property': 'id'}

# %%
G2.base_params()
# Out:
# {'direction': 'UNDIRECTED',
#  'node_label': 'Node',
#  'relationship_type': 'has',
#  'identifier_property': 'id'}

# %%
nx.draw(G1)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="vis.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
nx.draw(G2)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="vis.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
